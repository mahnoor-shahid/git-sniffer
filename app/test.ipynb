# %%
import pandas as pd
import os
from sentence_transformers import SentenceTransformer
import hdbscan

meta = pd.read_csv('D:\github_analyzer\data\metadata\combined_metadata.csv')
# summaries = pd.read_csv('D:\github_analyzer\data\\analysis\\readme_summaries.csv')

# df = meta.merge(summaries, on='full_name')
# df['text'] = df['description'] + ' ' + df['Summary']
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\g'
# <>:6: SyntaxWarning: invalid escape sequence '\g'
# C:\Users\Mahnoor\AppData\Local\Temp\ipykernel_23160\7990449.py:6: SyntaxWarning: invalid escape sequence '\g'
#   meta = pd.read_csv('D:\github_analyzer\data\metadata\combined_metadata.csv')

# %%
meta[['full_name', 'stargazers_count', 'forks_count', 'language', 'description', 'topics']]
# Out:
#              full_name  stargazers_count  forks_count  watchers_count  \
# 0  biopython/biopython              4286         1734            4286
#
#   language                                        description  \
# 0   Python  Official git repository for Biopython (origina...
#
#                                               topics
# 0  ['bioinformatics', 'biopython', 'dna', 'genomi...

# %%
meta.columns
# Out:
# Index(['id', 'node_id', 'name', 'full_name', 'private', 'owner', 'html_url',
#        'description', 'fork', 'url', 'forks_url', 'keys_url',
#        'collaborators_url', 'teams_url', 'hooks_url', 'issue_events_url',
#        'events_url', 'assignees_url', 'branches_url', 'tags_url', 'blobs_url',
#        'git_tags_url', 'git_refs_url', 'trees_url', 'statuses_url',
#        'languages_url', 'stargazers_url', 'contributors_url',
#        'subscribers_url', 'subscription_url', 'commits_url', 'git_commits_url',
#        'comments_url', 'issue_comment_url', 'contents_url', 'compare_url',
#        'merges_url', 'archive_url', 'downloads_url', 'issues_url', 'pulls_url',
#        'milestones_url', 'notifications_url', 'labels_url', 'releases_url',
#        'deployments_url', 'created_at', 'updated_at', 'pushed_at', 'git_url',
#        'ssh_url', 'clone_url', 'svn_url', 'homepage', 'size',
#        'stargazers_count', 'watchers_count', 'language', 'has_issues',
# ...

# %%
data = pd.read_csv('D:\\github_analyzer\\data\\subscribers\\nilmtk++nilmtk.csv')
data
# Out:
#    repo_owner repo_name subscriber_login  subscriber_id  \
# 0      nilmtk    nilmtk       nipunbatra          60985
# 1      nilmtk    nilmtk           asez73         500161
# 2      nilmtk    nilmtk        sumangiri        6947484
# 3      nilmtk    nilmtk      Bittencourt         351855
# 4      nilmtk    nilmtk     christylernz        7918463
# ..        ...       ...              ...            ...
# 61     nilmtk    nilmtk           mfigbr       23726811
# 62     nilmtk    nilmtk      danielp2797       56739984
# 63     nilmtk    nilmtk          geduxas       18700450
# 64     nilmtk    nilmtk       fariddinar       64606990
# 65     nilmtk    nilmtk          karimcy      105865230
#
#                      subscriber_url
# 0     https://github.com/nipunbatra
# 1         https://github.com/asez73
# 2      https://github.com/sumangiri
# 3    https://github.com/Bittencourt
# 4   https://github.com/christylernz
# ..                              ...
# ...

# %%
# Load pre-trained SentenceTransformer model
model = SentenceTransformer('all-MiniLM-L6-v2')

# Compute embeddings for the combined text
embeddings = model.encode(df['text'].tolist(), show_progress_bar=True)

# Apply HDBSCAN clustering
clusterer = hdbscan.HDBSCAN(min_cluster_size=2, min_samples=1, metric='euclidean')
df['cluster'] = clusterer.fit_predict(embeddings)

# Analyze the resulting clusters
print(df[['full_name', 'description', 'Summary', 'cluster']])
# Out:
# Batches: 100%|██████████| 2/2 [00:00<00:00, 12.22it/s]
#                              full_name  \
# 0                   google/deepvariant
# 1               ivanseidel/IAMDinosaur
# 2                  broadinstitute/gatk
# 3   peteanderson80/bottom-up-attention
# 4          griffithlab/rnaseq_tutorial
# 5                            vgteam/vg
# 6         primaryobjects/AI-Programmer
# 7           kblin/ncbi-genome-download
# 8                      arq5x/bedtools2
# 9                       evo-design/evo
# 10                  google/deepvariant
# 11              ivanseidel/IAMDinosaur
# 12                 broadinstitute/gatk
# 13  peteanderson80/bottom-up-attention
# 14         griffithlab/rnaseq_tutorial
# 15                           vgteam/vg
# 16        primaryobjects/AI-Programmer
# 17          kblin/ncbi-genome-download
# 18                     arq5x/bedtools2
# 19                      evo-design/evo
# 20                  google/deepvariant
# ...

# %%
df
# Out:
#            id                           node_id                  name  \
# 0   111751293  MDEwOlJlcG9zaXRvcnkxMTE3NTEyOTM=           deepvariant
# 1    48660863  MDEwOlJlcG9zaXRvcnk0ODY2MDg2Mw==           IAMDinosaur
# 2    27452807  MDEwOlJlcG9zaXRvcnkyNzQ1MjgwNw==                  gatk
# 3    92554388  MDEwOlJlcG9zaXRvcnk5MjU1NDM4OA==   bottom-up-attention
# 4    22481024  MDEwOlJlcG9zaXRvcnkyMjQ4MTAyNA==       rnaseq_tutorial
# 5    24727800  MDEwOlJlcG9zaXRvcnkyNDcyNzgwMA==                    vg
# 6     7779270      MDEwOlJlcG9zaXRvcnk3Nzc5Mjcw         AI-Programmer
# 7    57950916  MDEwOlJlcG9zaXRvcnk1Nzk1MDkxNg==  ncbi-genome-download
# 8    15059334  MDEwOlJlcG9zaXRvcnkxNTA1OTMzNA==             bedtools2
# 9   759144653                      R_kgDOLT-gzQ                   evo
# 10  111751293  MDEwOlJlcG9zaXRvcnkxMTE3NTEyOTM=           deepvariant
# 11   48660863  MDEwOlJlcG9zaXRvcnk0ODY2MDg2Mw==           IAMDinosaur
# ...
